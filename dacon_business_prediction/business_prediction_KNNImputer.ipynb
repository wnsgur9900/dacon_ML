# %%
import pandas as pd

# %%
train = pd.read_csv("data-files/train.csv")
test = pd.read_csv("data-files/test.csv")

# %%
except_cols = ["ID", "성공확률"]
X_train = train.drop(columns=except_cols)
y_train = train["성공확률"]
X_test = test.drop(columns=["ID"])

# %%
cat_cols = X_train.select_dtypes(include="object").columns.tolist()
X_train = pd.get_dummies(X_train, columns=cat_cols)
X_test = pd.get_dummies(X_test, columns=cat_cols)

# %%
X_train, X_test = X_train.align(X_test, join="left", axis=1, fill_value=0)

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer(n_neighbors=3)
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train_imputed, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(X_test_imputed)

# %%
import numpy as np

# %%
y_pred = np.round(y_pred, 3)

# %%
submission = pd.DataFrame({
    'ID': test['ID'],
    '성공확률': y_pred
})

submission.to_csv('submission_knn.csv', index=False)

# %%
submission
# Out:
#              ID   성공확률
# 0     TEST_0000  0.535
# 1     TEST_0001  0.464
# 2     TEST_0002  0.478
# 3     TEST_0003  0.552
# 4     TEST_0004  0.592
# ...         ...    ...
# 1750  TEST_1750  0.560
# 1751  TEST_1751  0.590
# 1752  TEST_1752  0.575
# 1753  TEST_1753  0.544
# 1754  TEST_1754  0.475
#
# [1755 rows x 2 columns]

# %%
# -----------------------------------------------------------
# MAE 측정

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X_train_sub, X_val, y_train_sub, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
model_2 = RandomForestRegressor(n_estimators=100, random_state=42)
model_2.fit(X_train_sub, y_train_sub)

y_val_pred = model.predict(X_val)
# Out:
# c:\Users\human\.conda\envs\python-env-311\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(

# %%
mse = mean_squared_error(y_val, y_val_pred)
rmse = mse**0.5

print(f"검증 RMSE: {rmse:.4f}")
# Out:
# 검증 RMSE: 0.1056

# %%
from sklearn.metrics import mean_absolute_error

# 예측 결과 y_val_pred를 이용해서
mae = mean_absolute_error(y_val, y_val_pred)

print(f"검증 MAE: {mae:.4f}")
# Out:
# 검증 MAE: 0.0855

# %%
submission.to_csv('submission_KNN.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 submission.to_csv('submission_KNN.csv', index=False)
#
# NameError: name 'submission' is not defined
